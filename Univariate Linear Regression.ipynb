# %% [markdown]
# <a href="https://colab.research.google.com/github/sunkusun9/ML2022_1/blob/main/Univariate%20Linear%20Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 단일 변수 선형 회귀 모델

# %% [markdown]
# $\hat{y}=\beta_0 + \beta_1x$

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 선형 회귀 분석을 보이기 위한 임의의 데이터 생성

# %%
# 표준정규분포(평균=0, 분산=1인 정규분포)를 따르는 임의의 변수 100개를 생성
x = np.random.normal(size=100)

# %%
# x의 히스토그램 
plt.hist(x, bins=15)
plt.xlabel("x")
plt.ylabel("freq")
plt.show()

# %%
# 기울기가 beta_1, 절편이 beta_0 이고 표준편차를 0.2의 노이즈를 주어 y값을 생성
beta_0, beta_1, noise = 2.5, 3.2, 1.0
y = x * beta_1 + beta_0 + np.random.normal(scale=0.2, size=100)

# %%
# x, y의 산포도 그래프 출력
plt.scatter(x, y, s=3)
plt.axhline(0, linestyle='dashed')
plt.axvline(0, linestyle='dashed')
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %% [markdown]
# 임의로 생성한 데이터셋으로 단일변수 선형회귀모델을 학습시켜보자.
